# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\МАСЯНЯ'

# %%
movies = pd.read_csv('Movie-Ratings.csv')

# %%
len(movies) #599 rows
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns = ['Film', 'Genre', 'RottenTomatoes', 'AudienceRatings', 'BudgetMils', 'ReleaseYear' ]

# %%
movies.head()
# Out:
#                     Film      Genre  RottenTomatoes  AudienceRatings  \
# 0  (500) Days of Summer      Comedy              87               81
# 1            10,000 B.C.  Adventure               9               44
# 2             12 Rounds      Action              30               52
# 3              127 Hours  Adventure              93               84
# 4              17 Again      Comedy              55               70
#
#    BudgetMils  ReleaseYear
# 0           8         2009
# 1         105         2008
# 2          20         2009
# 3          18         2010
# 4          20         2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null category
# Genre              559 non-null category
# RottenTomatoes     559 non-null int64
# AudienceRatings    559 non-null int64
# BudgetMils         559 non-null int64
# ReleaseYear        559 non-null int64
# dtypes: category(2), int64(4)
# memory usage: 43.9 KB

# %%
movies.describe()
# Out:
#        RottenTomatoes  AudienceRatings  BudgetMils  ReleaseYear
# count      559.000000       559.000000  559.000000   559.000000
# mean        47.309481        58.744186   50.236136  2009.152057
# std         26.413091        16.826887   48.731817     1.362632
# min          0.000000         0.000000    0.000000  2007.000000
# 25%         25.000000        47.000000   20.000000  2008.000000
# 50%         46.000000        58.000000   35.000000  2009.000000
# 75%         70.000000        72.000000   65.000000  2010.000000
# max         97.000000        96.000000  300.000000  2011.000000

# %%
movies['Film'] = movies['Film'].astype('category')

# %%
movies['Genre'] = movies['Genre'].astype('category')

# %%
movies['ReleaseYear'] = movies['ReleaseYear'].astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null category
# Genre              559 non-null category
# RottenTomatoes     559 non-null int64
# AudienceRatings    559 non-null int64
# BudgetMils         559 non-null int64
# ReleaseYear        559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
j = sns.jointplot(data = movies, x = 'RottenTomatoes', y = 'AudienceRatings', kind = 'resid
    ')
# Out:
#   File "<ipython-input-30-a1fdadca8d54>", line 1
#     j = sns.jointplot(data = movies, x = 'RottenTomatoes', y = 'AudienceRatings', kind = 'resid
#                                                                                                ^
# SyntaxError: EOL while scanning string literal

# %%
k = sns.jointplot(data = movies, y = 'BudgetMils', x = 'AudienceRatings', kind = 'kde')

# %%
ml = sns.distplot(movies.BudgetMils, bins = 15)

# %%
gen = [movies[movies.Genre == 'Drama'].BudgetMils, movies[movies.Genre == 'Thriller'].BudgetMils]


plt.hist(gen, bins = 10, stacked = True)
plt.show()

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
list1 = list()
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
plt.hist(movies[movies.Genre == gen].BudgetMils, bins = 10, stacked = True)
plt.show()

# %%
gen = movies.Genre.cat.categories

# %%
lis2 = list()
for gen1 in movies.Genre.cat.categories:
    list.append.movies[movies.Genre == gen1].BudgetMils
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-d97bc4afe3df> in <module>()
#       1 lis2 = list()
#       2 for gen1 in movies.Genre.cat.categories:
# ----> 3     list.append.movies[movies.Genre == gen1].BudgetMils
#
# AttributeError: 'method_descriptor' object has no attribute 'movies'

# %%
vis1 = sns.lmplot(data = movies, x = 'RottenTomatoes', y = 'AudienceRatings', fit_reg = False, hue = 'Genre')

# %%
k1 = sns.kdeplot(movies.RottenTomatoes, movies.AudienceRatings,\
                cmap = 'Reds')
k2 = sns.kdeplot(movies.RottenTomatoes, movies.AudienceRatings, shade = True, shade_lowest =False, \
                cmap = 'Reds')

# %%
sns.set_style('dark')
k3 = sns.kdeplot(movies.BudgetMils, movies.RottenTomatoes)

# %%
f, axes = plt.subplots(2,2, figsize = (8,8))
k2 = sns.kdeplot(movies.BudgetMils, movies.AudienceRatings, ax = axes[0,0])
k3 = sns.kdeplot(movies.BudgetMils, movies.RottenTomatoes, ax = axes[1,0])
k4 = sns.kdeplot(movies.AudienceRatings, movies.RottenTomatoes, ax = axes[1,1])
k2.set(xlim=(-10,110))
k4.set(xlim=(10,100))
k3.set(xlim=(-15,160))
# Out:
# [(-15, 160)]

# %%
bp = sns.boxplot(data = movies, x = 'Genre', y='RottenTomatoes')

# %%
vp = sns.violinplot(data = movies, x = 'Genre', y = "RottenTomatoes")

# %%
bp = sns.boxplot(data = movies[movies.Genre == 'Drama'], x = 'ReleaseYear', y='RottenTomatoes')

# %%
vp = sns.violinplot (data = movies[movies.Genre == 'Drama'], x = 'ReleaseYear', y='RottenTomatoes', pallette = 'YlOrRd')

# %%
g = sns.FacetGrid(movies, row = 'Genre', col = 'ReleaseYear', hue= 'Genre')
kws = dict(s = 50, linewidth = 0.5, edgecolor = 'black')
g = g.map(plt.scatter, 'RottenTomatoes', 'AudienceRatings', **kws)
g.set(xlim = (0,100), ylim = (0,100))

for ax in g.axes.flat:
    ax.plot((0,100), (0,100), c= 'grey', ls = '--')
g.add_legend()

# %%
h = sns.FacetGrid(movies, row = 'Genre', col = 'ReleaseYear', hue = 'Genre')
kwh = dict(linewidth = 0.5, edgecolor = 'black')
h.map(plt.hist, 'RottenTomatoes', **kwh)

for ax in g.

# %%
sns.set_style('whitegrid', {'axis.facecolor':'black'})
f, axes = plt.subplots(2,2, figsize=(15,15))
k2 = sns.kdeplot(movies.BudgetMils, movies.AudienceRatings, \
                 shade = True, shade_lowest = False, cmap = 'Blues', \
                 ax = axes[0,0])
ka2 = sns.kdeplot(movies.BudgetMils, movies.AudienceRatings, shade = True, shade_lowest =False, \
                cmap = 'Reds', ax = axes[0,0])
k3 = sns.kdeplot(movies.BudgetMils, movies.RottenTomatoes, \
                 shade = True, shade_lowest = False, cmap ='inferno',
                 ax = axes[1,0])

axes[1,1].hist(movies.BudgetMils, edgecolor = 'black')

vp = sns.violinplot(data = movies[movies.Genre == 'Drama'], x = 'ReleaseYear', y='RottenTomatoes', pallette = 'YlOrRd', ax = axes[0,1])


k2.set(xlim=(-10,110))
k4.set(xlim=(10,100))
k3.set(xlim=(-15,160))
# Out:
# [(-15, 160)]

# %%
list1 = list()
mylabels = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMils)
    mylabels.append(gen)

fig, ax = plt.subplots()
fig.set_size_inches(11.7,8.27)
sns.set_style('white')
h = plt.hist(list1, bins = 30, stacked = True, rwidth = 1, edgecolor = 'black', label = mylabels
plt.title('Movies Budged Distribution', fontsize = 25, color = 'red', fontname = 'Arial')
plt.xlabel('Movies Budget', fontsize = 15)
plt.ylabel('Number of Movies', fontsize = 15)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.legend(frameon = True, fontsize = 20, fancybox = True)
plt.show()
# Out:
#   File "<ipython-input-57-b5fd08abc9b2>", line 11
#     plt.title('Movies Budged Distribution', fontsize = 25, color = 'red', fontname = 'Arial')
#       ^
# SyntaxError: invalid syntax
